# %%
import requests
import json
import pandas as pd
from google.cloud import storage
from google.cloud import bigquery
import sys
import time
import random
import datetime

# %%
#storage_client = storage.Client()
storage_client = storage.Client.from_service_account_json('../credentials/house-297220-545f62b34773.json')

# segments boundaries: split territory on the equal horizontal slices
bucket = storage_client.get_bucket('cities_boundaries')
bounds_blob = bucket.get_blob('usa/new_york.json')
bounds = json.loads(bounds_blob.download_as_string(client=None))

# %%
def make_top_url(bounds, request_id):
    part_1 = 'https://www.zillow.com/search/GetSearchPageState.htm?searchQueryState={"pagination":{},"mapBounds":{'
    part_2 = '"west":{west},"east":{east},"south":{south},"north":{north}'.format(**bounds)
    part_3 = '},"isMapVisible":true,"filterState":{"sortSelection":{"value":"globalrelevanceex"},"isAllHomes":{"value":true},"isSingleFamily":{"value":false},"isCondo":{"value":false},"isManufactured":{"value":false},"isLotLand":{"value":false},"isApartment":{"value":false}},"isListVisible":true,"mapZoom":8}&wants={"cat1":["mapResults"]}&requestId='
    
    return part_1 + part_2 + part_3 + str(request_id)


def make_raw_data(zpid):
    raw_data = {"operationName":"ForSaleDoubleScrollFullRenderQuery","variables":{"zpid":zpid,"contactFormRenderParameter":{"zpid":zpid,"platform":"desktop","isDoubleScroll":True}},"clientVersion":"home-details/6.0.11.3286.master.758d5aa","queryId":"2f76b63ef5b3d1d3398289fbdeee967c"}
    
    return raw_data


def make_low_url(zpid):
    low_url_template = 'https://www.zillow.com/graphql/?zpid={}&contactFormRenderParameter=&queryId=2f76b63ef5b3d1d3398289fbdeee967c&operationName=ForRentDoubleScrollFullRenderQuery'

    return low_url_template.format(zpid)

# %%
# headers
user_agent_list = [
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
]


headers_top = {
    'Host': 'www.zillow.com',
    'Accept': 'Accept: */*',
    'Accept-Language': 'en-GB,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Cache-Control': 'max-age=0'
}


headers_low = {
    'Host': 'www.zillow.com',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'content-type': 'text/plain',
    'Origin': 'https://www.zillow.com'
}

# %%
def transform_data(raw_details, zpid):
    # function transforms json details to data frame format
    
    # create dict to store the data to
    data = {'zpid': zpid, 'date_uploaded': datetime.datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S.%f UTC')}
    
    # high level details
    high_level_data = raw_details.json()['data']['property']
    hig_level_props = ['city', 'homeStatus', 'price', 'streetAddress', 'datePosted', 'zipcode', 'latitude', 'longitude']
    for k in hig_level_props:
        if k in high_level_data.keys() and high_level_data[k] is not None:
            data[k] = high_level_data[k]

    # low level details
    low_level_data = raw_details.json()['data']['property']['resoFacts']
    low_level_props = [ 'bedrooms', 'bathrooms', 'bathroomsFull', 'bathroomsThreeQuarter', 'bathroomsHalf', 'bathroomsOneQuarter', 'bathroomsPartial', 'mainLevelBathrooms', 'basement', 'flooring', 'heating', 'hasHeating', 'cooling', 'hasCooling', 'appliances', 'laundryFeatures', 'fireplaces', 'fireplaceFeatures', 'hasFireplace', 'furnished', 'commonWalls', 'buildingArea', 'livingArea', 'aboveGradeFinishedArea', 'belowGradeFinishedArea', 'virtualTour', 'parking', 'parkingFeatures', 'garageSpaces', 'coveredSpaces', 'hasAttachedGarage', 'hasGarage', 'openParkingSpaces', 'hasOpenParking', 'carportSpaces', 'hasCarport', 'otherParking', 'accessibilityFeatures', 'levels', 'stories', 'entryLevel', 'entryLocation', 'hasPrivatePool', 'hasSpa', 'spaFeatures', 'exteriorFeatures', 'patioAndPorchFeatures', 'fencing', 'view', 'hasView', 'hasWaterfrontView', 'waterfrontFeatures', 'frontageType', 'frontageLength', 'topography', 'woodedArea', 'vegetation', 'canRaiseHorses', 'lotSize', 'lotSizeDimensions', 'otherStructures', 'additionalParcelsDescription', 'hasAdditionalParcels', 'parcelNumber', 'hasAttachedProperty', 'hasLandLease', 'landLeaseAmount', 'zoning', 'zoningDescription', 'homeType', 'architecturalStyle', 'constructionMaterials', 'foundationDetails', 'roofType', 'windowFeatures', 'propertyCondition', 'isNewConstruction', 'yearBuilt', 'developmentStatus', 'yearBuiltEffective', 'onMarketDate', 'builderModel', 'builderName', 'hasHomeWarranty', 'electric', 'hasElectricOnProperty', 'gas', 'sewer', 'waterSources', 'utilities', 'greenBuildingVerificationType', 'greenEnergyEfficient', 'greenIndoorAirQuality', 'greenSustainability', 'greenWaterConservation', 'numberOfUnitsInCommunity', 'numberOfUnitsVacant', 'storiesTotal', 'hasPetsAllowed', 'hasRentControl', 'buildingFeatures', 'structureType', 'buildingName', 'elementarySchool', 'elementarySchoolDistrict', 'middleOrJuniorSchool', 'middleOrJuniorSchoolDistrict', 'highSchool', 'highSchoolDistrict', 'securityFeatures', 'communityFeatures', 'isSeniorCommunity', 'cityRegion', 'associationFee', 'hasAssociation', 'associationAmenities', 'associationFeeIncludes', 'associationName', 'associationPhone', 'associationFee2', 'associationName2', 'associationPhone2', 'taxAssessedValue', 'taxAnnualAmount', 'listingId', 'buildingAreaSource']
    for k in low_level_props:
        if k in low_level_data.keys() and low_level_data[k] is not None and type(low_level_data[k]) != dict:
            value = low_level_data[k]
            if type(value) == list:
                value = ' | '.join(value)

            data[k] = value
    
    return data

# %%
def get_price_history(raw_details, zpid):
    if 'priceHistory' in raw_details.json()['data']['property'].keys():
        history = []
        for price_change in raw_details.json()['data']['property']['priceHistory']:
            history_date = datetime.datetime.fromtimestamp(int(price_change['time']/1000)).strftime('%Y-%m-%d %H:%M:%S.%f UTC')
            history_event = price_change['event']
            history_price = price_change['price']
            history_source = price_change['source']
            
            history.append({'zpid': zpid, 'date': history_date, 'event': history_event, 'price': history_price, 'source': history_source})
        
    else:
        history = False
    
    return history

# %%
query = """
SELECT zpid
  , price
FROM (
  SELECT zpid
    , price
    , date_uploaded
    , MAX(date_uploaded) OVER (PARTITION BY zpid) AS date_uploaded_last
  FROM `house-297220.usa.new_york_sale`
) AS a
WHERE date_uploaded = date_uploaded_last
"""

bigquery_client = bigquery.Client.from_service_account_json('../credentials/house-297220-545f62b34773.json')

query_job = bigquery_client.query(query)

existing_zpids_raw = query_job.result() 

existing_zpids = {}
for row in existing_zpids_raw:
    existing_zpids[str(row.zpid)] = row.price

# %%
for segment in bounds.keys():
    print(segment)
    # initialize metadata
    writen_objects = 0
    write_errors = 0
    total_results = 0
    broken_responses_top = ''
    broken_responses_low = []
    errors = []
    bq_errors = []
    
    
    url_top = make_top_url(bounds[segment], segment)
    headers_top['User-Agent'] = random.choice(user_agent_list)
    response_top = requests.get(url_top, headers=headers_top)

    if response_top.status_code != 200:
        time.sleep(60)
        headers_top['User-Agent'] = random.choice(user_agent_list)
        response_top = requests.get(url_top, headers=headers_top)

    if response_top.status_code != 200:
        broken_responses_top = str(response_top.status_code)

    else:
        if 'totalResultCount' in response_top.json()['cat1']['searchList'].keys():
            total_results = response_top.json()['cat1']['searchList']['totalResultCount']
        else:
            total_results = 'unknown'
        
        try:
            for result in response_top.json()['cat1']['searchResults']['mapResults']:
                # only if zpid and (if zpid doesn't exist yet or it had different price)
                if 'zpid' in result.keys() and (result['zpid'] not in existing_zpids.keys() or existing_zpids[result['zpid']] != int(result['hdpData']['homeInfo']['price'])):
                    try:                    
                        zpid = result['zpid']


                        url_low = make_low_url(zpid)
                        raw_data = make_raw_data(zpid)
                        headers_low['User-Agent'] = random.choice(user_agent_list)
                        raw_details = requests.post(url_low, headers=headers_low, json=raw_data)

                        if raw_details.status_code != 200:
                            time.sleep(60)
                            headers_low['User-Agent'] = random.choice(user_agent_list)
                            raw_details = requests.post(url_low, headers=headers_low, json=raw_data)

                        if raw_details.status_code != 200:
                            broken_responses_low.append(str(raw_details.status_code))

                        else:
                            data = transform_data(raw_details, zpid)                          
                            bq_error = bigquery_client.insert_rows_json('house-297220.usa.new_york_sale', [data,])
                            if bq_error == []:
                                writen_objects += 1
                            else:
                                write_errors += 1
                                bq_errors.append(str(bq_error))


                            price_history = get_price_history(raw_details, zpid)
                            if price_history != False:
                                e = bigquery_client.insert_rows_json('house-297220.usa.new_york_sale_price_history', price_history)

                    except:
                        continue
                    time.sleep(3)
        
        except:
            ee = str(sys.exc_info()[0])
            errors.append(ee)
            print(ee)
            time.sleep(3)
            continue
            

        
        
        metadata = {
            'type': 'sale',
            'city': 'New York',
            'segment': segment,
            'date': datetime.datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S.%f UTC'),
            'total_results': total_results,
            'writen_objects': writen_objects,
            'write_errors': write_errors,
            'broken_responses_top': broken_responses_top,
            'broken_responses_low': ' | '.join(broken_responses_low),
            'errors': ' | '.join(errors),
            'bq_errors': ' | '.join(bq_errors)
        } 
        
        print(metadata)
        
        try:
            e = bigquery_client.insert_rows_json('house-297220.usa.metadata', [metadata,])
            
        except:
            continue
# Out:
# 1
# {'type': 'sale', 'city': 'New York', 'segment': '1', 'date': '2020-12-21 12:21:15.232264 UTC', 'total_results': 32, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
#
 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 139
# {'type': 'sale', 'city': 'New York', 'segment': '139', 'date': '2020-12-21 15:14:37.870837 UTC', 'total_results': 95, 'writen_objects': 29, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 140
# <class 'KeyError'>
# 141
# {'type': 'sale', 'city': 'New York', 'segment': '141', 'date': '2020-12-21 15:16:27.439410 UTC', 'total_results': 80, 'writen_objects': 13, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 142
# {'type': 'sale', 'city': 'New York', 'segment': '142', 'date': '2020-12-21 15:17:40.446267 UTC', 'total_results': 109, 'writen_objects': 15, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 143
# {'type': 'sale', 'city': 'New York', 'segment': '143', 'date': '2020-12-21 15:19:33.305161 UTC', 'total_results': 105, 'writen_objects': 25, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 144
# {'type': 'sale', 'city': 'New York', 'segment': '144', 'date': '2020-12-21 15:21:45.290844 UTC', 'total_results': 85, 'writen_objects': 29, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 145
# {'type': 'sale', 'city': 'New York', 'segment': '145', 'date': '2020-12-21 15:24:41.422830 UTC', 'total_results': 116, 'writen_objects': 38, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 146
# <class 'KeyError'>
# 147
# <class 'KeyError'>
# 148
# <class 'KeyboardInterrupt'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-2dba97833e72> in <module>
#      67                         continue
# ---> 68                     time.sleep(3)
#      69
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-2dba97833e72> in <module>
#      72             errors.append(ee)
#      73             print(ee)
# ---> 74             time.sleep(3)
#      75             continue
#      76
#
# KeyboardInterrupt:

# %%
for segment in bounds.keys():
    if int(segment) >= 218:
        print(segment)
        # initialize metadata
        writen_objects = 0
        write_errors = 0
        total_results = 0
        broken_responses_top = ''
        broken_responses_low = []
        errors = []
        bq_errors = []


        url_top = make_top_url(bounds[segment], str(int(segment)-217))
        headers_top['User-Agent'] = random.choice(user_agent_list)
        response_top = requests.get(url_top, headers=headers_top)

        if response_top.status_code != 200:
            print(response_top.status_code)
            time.sleep(60)
            headers_top['User-Agent'] = random.choice(user_agent_list)
            response_top = requests.get(url_top, headers=headers_top)

        if response_top.status_code != 200:
            broken_responses_top = str(response_top.status_code)

        else:
            if 'totalResultCount' in response_top.json()['cat1']['searchList'].keys():
                total_results = response_top.json()['cat1']['searchList']['totalResultCount']
            else:
                total_results = 'unknown'

            try:
                for result in response_top.json()['cat1']['searchResults']['mapResults']:
                    # only if zpid and (if zpid doesn't exist yet or it had different price)
                    if 'zpid' in result['zpid'] and result['zpid'] in existing_zpids.keys():
                        print('{} already exists'.format(result['zpid']))
                        
                    if 'zpid' in result.keys() and (result['zpid'] not in existing_zpids.keys() or existing_zpids[result['zpid']] != int(result['hdpData']['homeInfo']['price'])):
                        
                        try:
                            print(zpid)
                            zpid = result['zpid']

                            url_low = make_low_url(zpid)
                            raw_data = make_raw_data(zpid)
                            headers_low['User-Agent'] = random.choice(user_agent_list)
                            raw_details = requests.post(url_low, headers=headers_low, json=raw_data)

                            if raw_details.status_code != 200:
                                time.sleep(60)
                                headers_low['User-Agent'] = random.choice(user_agent_list)
                                raw_details = requests.post(url_low, headers=headers_low, json=raw_data)

                            if raw_details.status_code != 200:
                                broken_responses_low.append(str(raw_details.status_code))

                            else:
                                data = transform_data(raw_details, zpid)                          
                                bq_error = bigquery_client.insert_rows_json('house-297220.usa.new_york_sale', [data,])
                                if bq_error == []:
                                    writen_objects += 1
                                else:
                                    write_errors += 1
                                    bq_errors.append(str(bq_error))


                                price_history = get_price_history(raw_details, zpid)
                                if price_history != False:
                                    e = bigquery_client.insert_rows_json('house-297220.usa.new_york_sale_price_history', price_history)

                                    
                        except:
                            continue
                        time.sleep(2)

                        
            except:
                ee = str(sys.exc_info()[0])
                errors.append(ee)
                print(ee)
                time.sleep(2)
                continue




            metadata = {
                'type': 'sale',
                'city': 'New York',
                'segment': segment,
                'date': datetime.datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S.%f UTC'),
                'total_results': total_results,
                'writen_objects': writen_objects,
                'write_errors': write_errors,
                'broken_responses_top': broken_responses_top,
                'broken_responses_low': ' | '.join(broken_responses_low),
                'errors': ' | '.join(errors),
                'bq_errors': ' | '.join(bq_errors)
            } 

            print(metadata)

            try:
                e = bigquery_client.insert_rows_json('house-297220.usa.metadata', [metadata,])

            except:
                continue
# Out:
# 218
# 2110660093
# 38619425
# 39460889
# 38930247
# 31549679
# 38750570
# 38899448
# 38938969
# 39459038
# 72094787
# 2078210698
# 2080381087
# 38930892
# 83937647
# 38938753
# 38929339
# 31550477
# 2077796725
# 68299398
# 2078208714
# 2079093551
# 59607319
# 38750438
# 38930557
# {'type': 'sale', 'city': 'New York', 'segment': '218', 'date': '2020-12-23 15:33:54.167781 UTC', 'total_results': 28, 'writen_objects': 24, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 219
# <class 'KeyError'>
# 220
# 38938470
# 2077562020
# 38630195
# 55345199
# 2099587874
# 38950596
# 2077863901
# 96747369
# 38879675
# 38746613
# 38950794
# 2079566974
# 38621105
# 31546970
# 66465676
# 38630227
# 2077324843
# 31546431
# 38947487
# 2084114572
# 38628703
# 38879622
# 38950779
# 32028163
# {'type': 'sale', 'city': 'New York', 'segment': '220', 'date': '2020-12-23 15:35:20.979309 UTC', 'total_results': 24, 'writen_objects': 24, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 221
# 59612839
# 2077968993
# 2077517757
# 52961929
# 63735797
# 38879916
# 38879745
# 2078130398
# 31524046
# 38618446
# 250813474
# 2077570674
# 31525080
# 38950321
# 38879766
# 38746433
# 88857871
# 31526583
# 38621785
# 31524052
# 2076903659
# 38935486
# 317223940
# 248888409
# 2089446620
# 2077926834
# 38948659
# 38630094
# 32021266
# 38938287
# 38937185
# 38938346
# 2077740066
# 38935420
# 2081641148
# {'type': 'sale', 'city': 'New York', 'segment': '221', 'date': '2020-12-23 15:37:19.359024 UTC', 'total_results': 35, 'writen_objects': 35, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 222
# 2078137526
# 2076929198
# 31524664
# 2078136433
# 2111325684
# 38949123
# 38948883
# 2100360834
# 38947666
# 2079787750
# 31524010
# 38625373
# 31524669
# <class 'KeyError'>
# 223
# 2077649458
# 108628334
# 38949045
# 31540796
# 52961854
# 2077309774
# 162154873
# 2078261089
# 38949063
# 38949482
# 31540849
# 38935856
# 38724697
# 31542465
# 31523887
# 2097932940
# 2077012634
# 2078142325
# 38627416
# 32055598
# 238
# 2076849757
# <class 'KeyError'>
# 239
# 31503003
# 2077429288
# 2080683260
# 2080347917
# 299326869
# 31500149
# 2079476248
# 38659372
# 31502749
# 31975019
# 31966133
# 2079504821
# 31500615
# 31979960
# 162076449
# 31975078
# 2114026583
# 32066206
# 38659352
# 31974719
# {'type': 'sale', 'city': 'New York', 'segment': '239', 'date': '2020-12-23 15:50:54.893420 UTC', 'total_results': 71, 'writen_objects': 20, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 240
# 38690734
# 2076817392
# 31498886
# 31499908
# 2081280541
# 2080473473
# 38891824
# 2140838026
# 2111020254
# 38659201
# 31501718
# 59355996
# 32071478
# 31983557
# 2083583901
# <class 'KeyError'>
# 241
# <class 'KeyError'>
# 242
# 38891883
# 2083219101
# 2080725689
# 114471276
# 82652756
# 32091358
# 38704337
# 38659780
# 31295422
# 32100758
# 64430655
# 38658991
# 31499096
# {'type': 'sale', 'city': 'New York', 'segment': '242', 'date': '2020-12-23 15:52:28.188509 UTC', 'total_results': 71, 'writen_objects': 13, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 243
# 30620059
# 2082691512
# 318278412
# 38909512
# 72243855
# 2077024133
# 30621356
# 38697426
# 2079114224
# 2095494580
# 30620308
# 38890924
# 2080380698
# 30620312
# 2080383117
# 59274238
# 38704808
# 2080339302
# 38891068
# 30620730
# 32091640
# 31998752
# 31982327
# 30620884
# 2079068926
# 38704580
# 38704871
# 31989469
# 31998753
# 31982263
# 38704083
# 38657219
# 38657386
# 31999412
# {'type': 'sale', 'city': 'New York', 'segment': '243', 'date': '2020-12-23 15:54:22.565982 UTC', 'total_results': 109, 'writen_objects': 34, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 244
# 38704511
# 2077600595
# 32150144
# 2080380737
# 31496552
# 38706051
# 31496560
# 38660306
# 38889186
# 2107239274
# 30621620
# 31987046
# 31986839
# 2077468438
# 2080380763
# 31986856
# 38657343
# 38704807
# 38662294
# 38664257
# 38664254
# 38706245
# 32072662
# {'type': 'sale', 'city': 'New York', 'segment': '244', 'date': '2020-12-23 15:55:41.413662 UTC', 'total_results': 109, 'writen_objects': 23, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 245
# 38705081
# 2092074867
# 39845347
# 302827222
# 31990295
# 2078534961
# 31993690
# 32002757
# 2079460483
# 31996127
# 82652849
# 31996113
# 38918699
# 64575456
# 31986236
# 2077874099
# 38915687
# 31996032
# 2078678508
# 30623747
# 30621640
# 248845545
# 2078430036
# 119111134
# 32152341
# 2078066861
# 38698440
# 31988943
# 30622102
# 38705170
# 2112742686
# 32069644
# 38890860
# 38890859
# 38660911
# 69527315
# 2078637734
# 38889620
# 31987940
# 2078959035
# 32152346
# 2077694399
# 2078751311
# {'type': 'sale', 'city': 'New York', 'segment': '245', 'date': '2020-12-23 15:58:07.788647 UTC', 'total_results': 79, 'writen_objects': 43, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
#
# 2092276545
# 30567691
# 30630201
# 30615197
# 30612042
# 30567816
# 2078966421
# 2127815340
# 2077429500
# 30611869
# 30611870
# 30611868
# 30627025
# 2100282626
# 2085220625
# 32105411
# 30607678
# 30607664
# 30612183
# 30627683
# 32118139
# 30607638
# 32105706
# 32118130
# 32196629
# 68018723
# 31182247
# 68017108
# 32196765
# 30626605
# 31213269
# 32137275
# 31180589
# 32166290
# 30627807
# 32142313
# 30626818
# 30602328
# 32143330
# 89067402
# 83051414
# 68314928
# 32138433
# 167532448
# 64791951
# 30628459
# 38907505
# 30627503
# 32193962
# {'type': 'sale', 'city': 'New York', 'segment': '255', 'date': '2020-12-23 16:14:01.502699 UTC', 'total_results': 160, 'writen_objects': 54, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 256
# 32196479
# 32604420
# 38907025
# 38907641
# 30602868
# 30608561
# <class 'KeyError'>
# 257
# 30630752
# 112508099
# 30603492
# 40076917
# 2076893162
# 30630082
# 30568434
# 32109346
# <class 'KeyError'>
# 258
# 30642228
# 31210645
# <class 'KeyError'>
# 259
# 30636932
# 32595675
# 39972068
# 2098003811
# 30631336
# 32113235
# 55732596
# 2076802241
# <class 'KeyError'>
# 260
# 216108968
# 30643606
# 38870538
# 2076806978
# 30589907
# 32638819
# 2076806175
# 62646730
# 30601081
# 2078228149
# 2146050605
# 2077110334
# 30606400
# 30589895
# 32186900
# 30644381
# 83042370
# 30643859
# 30644858
# 30572815
# 30611292
# 79746927
# 30601285
# 32638942
# 32172243
# 83042206
# 30611204
# 30601193
# 30601192
# 38878188
# 31381957
# 30572458
# 30600961
# 32174639
# 30643627
# 30582465
# 30589568
# 83047059
# 83045477
# 30644034
# 89025532
# 30601014
# 30644012
# 30591012
# 30638047
# 30601010
# {'type': 'sale', 'city': 'New York', 'segment': '260', 'date': '2020-12-23 16:17:54.587405 UTC', 'total_results': 152, 'writen_objects': 46, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 261
# 32174008
# 38871666
# 30638814
# 2076843117
# 30601619
# 32182301
# 112501577
# {'type': 'sale', 'city': 'New York', 'segment': '261', 'date': '2020-12-23 16:18:18.723400 UTC', 'total_results': 113, 'writen_objects': 7, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 262
# 32175119
# 2077505610
# 2076852346
# 2076844627
# 64780419
# 30639849
# 30634218
# 83049672
# <class 'KeyError'>
# 263
# 30598543
# <class 'KeyError'>
# 264
# 30593064
# 2076826256
# 30631851
# 39992589
# 30597146
# 2076806739
# 2080381000
# <class 'KeyError'>
# 265
# <class 'KeyError'>
# 266
# 30584669
# 30579997
# 40048770
# 40048765
# 2078288665
# 2078855422
# 30647826
# 2080380917
# {'type': 'sale', 'city': 'New York', 'segment': '266', 'date': '2020-12-23 16:19:49.735722 UTC', 'total_results': 85, 'writen_objects': 8, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 267
# 2078271041
# 30665246
# 39834440
# 30646552
# 2077126229
# 30657249
# 30657888
# 30579848
# 30657825
# 64507787
# 30633280
# 83049426
# 39993928
# 30651444
# 30633250
# 30650730
# 31419225
# 31416445
# 83042716
# 30633213
# 30657211
# 30665197
# 30633196
# 30650694
# 30633184
# 30657677
# 30652677
# 83049661
# 83049648
# 30646611
# 30574104
# 30646597
# 30633593
# 30633080
# 30657575
# 83047571
# 30664976
# 30633058
# 30633039
# 30652038
# 30646489
# 39988521
# {'type': 'sale', 'city': 'New York', 'segment': '267', 'date': '2020-12-23 16:21:32.906920 UTC', 'total_results': 111, 'writen_objects': 42, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 268
# <class 'KeyError'>
# 269
# 30646504
# 68303219
# 39840997
# 39841591
# <class 'KeyError'>
# 270
# 38876300
# 30659840
# 40044892
# 40044883
# 39841073
# 30659642
# 2080438164
# 30575053
# 30659881
# 30655313
# 2082902659
# 32217933
# 30575020
# 30575086
# 30659626
# 30772715
# 30712640
# 30580949
# {'type': 'sale', 'city': 'New York', 'segment': '270', 'date': '2020-12-23 16:22:53.823357 UTC', 'total_results': 64, 'writen_objects': 18, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 271
# 30580964
# 39983861
# 30672933
# 2086652569
# {'type': 'sale', 'city': 'New York', 'segment': '271', 'date': '2020-12-23 16:23:07.919047 UTC', 'total_results': 64, 'writen_objects': 4, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 272
# 39999941
# 31365628
# 30656355
# 30775488
# 31364850
# 30656266
# 30661344
# 30672253
# 30773105
# 30666744
# 30774598
# 30667402
# 30774715
# 31365698
# 30660885
# 30661193
# 30773692
# 30577068
# 30773691
# 30672067
# 30765995
# 31414372
# 30660791
# 32272034
# 102750161
# 30667970
# 30655649
# 30673995
# {'type': 'sale', 'city': 'New York', 'segment': '272', 'date': '2020-12-23 16:24:24.987525 UTC', 'total_results': 89, 'writen_objects': 28, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 273
# 30660996
# 30776393
# <class 'KeyError'>
# 274
# 30690552
# 30579527
# 30579528
# 30776231
# 30779477
# 30663476
# 30663474
# 40012918
# 83046376
# 30669365
# 30685364
# 30663353
# 32297349
# 30663348
# 30683837
# 30684334
# 30663323
# 32297308
# 30663298
# 30776260
# 30778494
# 32300740
# 30768737
# 30684731
# 30768674
# 30669661
# 30686154
# 30776152
# 30766631
# 30768622
# 30775120
# 63656612
# 30685108
# 32275581
# {'type': 'sale', 'city': 'New York', 'segment': '274', 'date': '2020-12-23 16:26:11.143210 UTC', 'total_results': 109, 'writen_objects': 34, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 275
# 30674524
# 32300434
# 32300110
# 30767563
# <class 'KeyError'>
# 276
# 2076804500
# 32300176
# 30758386
# 2076803406
# 2078035729
# 32299787
# 30750724
# 32285943
# 30778185
# 32299681
# 30693337
# 30771271
# 30688172
# 32274166
# 32285859
# 30759442
# 79727140
# 30676763
# 30674761
# 30771458
# 32276498
# 30779100
# 30750753
# 30759299
# 30771243
# 30779072
# 30758036
# 30769034
# 30670019
# {'type': 'sale', 'city': 'New York', 'segment': '276', 'date': '2020-12-23 16:27:55.989336 UTC', 'total_results': 69, 'writen_objects': 29, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 277
# 30770505
# <class 'KeyError'>
# 278
# 30693470
# 30761184
# 32296441
# 30679910
# 32276955
# 30760856
# 30752732
# 30752728
# 30760465
# 30689152
# 30771641
# 30677574
# 30696977
# 30780061
# 30751538
# 30772496
# {'type': 'sale', 'city': 'New York', 'segment': '278', 'date': '2020-12-23 16:28:51.672997 UTC', 'total_results': 62, 'writen_objects': 16, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 279
# 30761501
# 30698583
# <class 'KeyError'>
# 280
# 32280511
# 40032674
# 30705863
# 244597727
# <class 'KeyError'>
# 281
# 30706404
# 63132626
# {'type': 'sale', 'city': 'New York', 'segment': '281', 'date': '2020-12-23 16:29:26.115302 UTC', 'total_results': 66, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 282
# 30681940
# 30681753
# 30682704
# 30717957
# 30702399
# 31263087
# 32317812
# 32318554
# 30718305
# 30765387
# 83043527
# 30785601
# 30717848
# {'type': 'sale', 'city': 'New York', 'segment': '282', 'date': '2020-12-23 16:30:13.416187 UTC', 'total_results': 68, 'writen_objects': 13, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 283
# 30784447
# 30788951
# <class 'KeyError'>
# 284
# 30788953
# 30788968
# 30711558
# <class 'KeyError'>
# 285
# 32219162
# 2078353856
# 2077320482
# <class 'KeyError'>
# 286
# 30707531
# <class 'KeyError'>
# 287
# 2082353658
# 30743350
# 2077040564
# 32292180
# 2076875178
# 2078076092
# 30741905
# 32224068
# 30741718
# 30741678
# 32222726
# 31272292
# 31272300
# 30735807
# 30722610
# 30743557
# 32222553
# 30743534
# 30741875
# {'type': 'sale', 'city': 'New York', 'segment': '287', 'date': '2020-12-23 16:31:45.371903 UTC', 'total_results': 79, 'writen_objects': 19, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 288
# 64558009
# 30744871
# <class 'KeyError'>
# 289
# 2077813724
# 142995806
# 2076803451
# 30730427
# <class 'KeyError'>
# 290
# 2080854887
# 32311597
# 2078809979
# 30737539
# 30737460
# 32225140
# 32225125
# 122176605
# 32223788
# 32225299
# 32325319
# 32223875
# 79730025
# 30748438
# {'type': 'sale', 'city': 'New York', 'segment': '290', 'date': '2020-12-23 16:32:58.276497 UTC', 'total_results': 65, 'writen_objects': 14, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 291
# <class 'KeyError'>
# 292
# 30738987
# {'type': 'sale', 'city': 'New York', 'segment': '292', 'date': '2020-12-23 16:33:04.871001 UTC', 'total_results': 56, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 293
# <class 'KeyError'>
# 294
# 32328463
# 32316910
# 32315447
# 32329382
# 32315577
# 2078966935
# 2079984390
# 30732673
# 2079984727
# 30790403
# 2077492732
# 30790033
# 2080714592
# 39210123
# 30740492
# 30789941
# 39044315
# 2081782172
# 2077907500
# 30732189
# 30789262
# {'type': 'sale', 'city': 'New York', 'segment': '294', 'date': '2020-12-23 16:34:19.506337 UTC', 'total_results': 33, 'writen_objects': 21, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 295
# 30790538
# 32316179
# 39182202
# 30732775
# 32316283
# 30789669
# 32331662
# 30789401
# 30732572
# 30789558
# 30789535
# 30789519
# {'type': 'sale', 'city': 'New York', 'segment': '295', 'date': '2020-12-23 16:34:50.516288 UTC', 'total_results': 52, 'writen_objects': 12, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 296
# 30732511
# 30732837
# 32338274
# 64647895
# 30732933
# 30732849
# 32333038
# {'type': 'sale', 'city': 'New York', 'segment': '296', 'date': '2020-12-23 16:35:13.142905 UTC', 'total_results': 22, 'writen_objects': 7, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 297
# 39042340
# 55543285
# 39094093
# {'type': 'sale', 'city': 'New York', 'segment': '297', 'date': '2020-12-23 16:35:21.789561 UTC', 'total_results': 12, 'writen_objects': 3, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 298
# 32336391
# 2078312306
# {'type': 'sale', 'city': 'New York', 'segment': '298', 'date': '2020-12-23 16:35:29.418145 UTC', 'total_results': 7, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 299
# {'type': 'sale', 'city': 'New York', 'segment': '299', 'date': '2020-12-23 16:35:30.201285 UTC', 'total_results': 3, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 300
# 2077134080
# 64475112
# 39858737
# {'type': 'sale', 'city': 'New York', 'segment': '300', 'date': '2020-12-23 16:35:41.293499 UTC', 'total_results': 11, 'writen_objects': 3, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 301
# 32360304
# 32340832
# 58578547
# {'type': 'sale', 'city': 'New York', 'segment': '301', 'date': '2020-12-23 16:35:53.594014 UTC', 'total_results': 15, 'writen_objects': 3, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 302
# 32360538
# 39195377
# <class 'KeyError'>
# 303
# 39195991
# {'type': 'sale', 'city': 'New York', 'segment': '303', 'date': '2020-12-23 16:36:08.134947 UTC', 'total_results': 10, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 304
# 87970821
# {'type': 'sale', 'city': 'New York', 'segment': '304', 'date': '2020-12-23 16:36:12.333022 UTC', 'total_results': 15, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 305
# 39206258
# 32355603
# 32357092
# 32355740
# 32362788
# {'type': 'sale', 'city': 'New York', 'segment': '305', 'date': '2020-12-23 16:36:25.028660 UTC', 'total_results': 18, 'writen_objects': 5, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 306
# 32372431
# 32363877
# {'type': 'sale', 'city': 'New York', 'segment': '306', 'date': '2020-12-23 16:36:32.711363 UTC', 'total_results': 14, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 307
# 32371674
# 39896575
# 32363757
# {'type': 'sale', 'city': 'New York', 'segment': '307', 'date': '2020-12-23 16:36:41.661836 UTC', 'total_results': 12, 'writen_objects': 3, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 308
# 32346483
# 32347927
# {'type': 'sale', 'city': 'New York', 'segment': '308', 'date': '2020-12-23 16:36:48.763689 UTC', 'total_results': 15, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 309
# 32348877
# {'type': 'sale', 'city': 'New York', 'segment': '309', 'date': '2020-12-23 16:36:53.084914 UTC', 'total_results': 12, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 310
# {'type': 'sale', 'city': 'New York', 'segment': '310', 'date': '2020-12-23 16:36:53.863242 UTC', 'total_results': 7, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 311
# 32373854
# 39150015
# {'type': 'sale', 'city': 'New York', 'segment': '311', 'date': '2020-12-23 16:36:59.174482 UTC', 'total_results': 10, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 312
# 119609713
# {'type': 'sale', 'city': 'New York', 'segment': '312', 'date': '2020-12-23 16:37:03.134267 UTC', 'total_results': 9, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 313
# {'type': 'sale', 'city': 'New York', 'segment': '313', 'date': '2020-12-23 16:37:04.203424 UTC', 'total_results': 6, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 314
# {'type': 'sale', 'city': 'New York', 'segment': '314', 'date': '2020-12-23 16:37:04.919465 UTC', 'total_results': 7, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 315
# 32366627
# {'type': 'sale', 'city': 'New York', 'segment': '315', 'date': '2020-12-23 16:37:09.877015 UTC', 'total_results': 9, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 316
# <class 'KeyError'>
# 317
# 2076829925
# {'type': 'sale', 'city': 'New York', 'segment': '317', 'date': '2020-12-23 16:37:17.038158 UTC', 'total_results': 12, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 318
# 63149914
# {'type': 'sale', 'city': 'New York', 'segment': '318', 'date': '2020-12-23 16:37:21.453436 UTC', 'total_results': 5, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 319
# 2078656371
# 58579309
# {'type': 'sale', 'city': 'New York', 'segment': '319', 'date': '2020-12-23 16:37:29.851876 UTC', 'total_results': 12, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 320
# {'type': 'sale', 'city': 'New York', 'segment': '320', 'date': '2020-12-23 16:37:31.130363 UTC', 'total_results': 8, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 321
# 32377763
# <class 'KeyError'>
# 322
# 32374941
# 38857122
# {'type': 'sale', 'city': 'New York', 'segment': '322', 'date': '2020-12-23 16:37:42.290464 UTC', 'total_results': 17, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 323
# <class 'KeyError'>
# 324
# <class 'KeyError'>
# 325
# {'type': 'sale', 'city': 'New York', 'segment': '325', 'date': '2020-12-23 16:37:48.129545 UTC', 'total_results': 8, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 326
# {'type': 'sale', 'city': 'New York', 'segment': '326', 'date': '2020-12-23 16:37:49.159383 UTC', 'total_results': 6, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 327
# {'type': 'sale', 'city': 'New York', 'segment': '327', 'date': '2020-12-23 16:37:49.879674 UTC', 'total_results': 9, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 328
# <class 'KeyError'>
# 329
# {'type': 'sale', 'city': 'New York', 'segment': '329', 'date': '2020-12-23 16:37:53.358839 UTC', 'total_results': 7, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 330
# 299460439
# {'type': 'sale', 'city': 'New York', 'segment': '330', 'date': '2020-12-23 16:37:57.602063 UTC', 'total_results': 3, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 331
# 55548668
# 39161001
# {'type': 'sale', 'city': 'New York', 'segment': '331', 'date': '2020-12-23 16:38:05.282324 UTC', 'total_results': 5, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 332
# {'type': 'sale', 'city': 'New York', 'segment': '332', 'date': '2020-12-23 16:38:06.362597 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 333
# {'type': 'sale', 'city': 'New York', 'segment': '333', 'date': '2020-12-23 16:38:07.225752 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 334
# {'type': 'sale', 'city': 'New York', 'segment': '334', 'date': '2020-12-23 16:38:07.892961 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 335
# {'type': 'sale', 'city': 'New York', 'segment': '335', 'date': '2020-12-23 16:38:08.615709 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 336
# {'type': 'sale', 'city': 'New York', 'segment': '336', 'date': '2020-12-23 16:38:09.482562 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 337
# {'type': 'sale', 'city': 'New York', 'segment': '337', 'date': '2020-12-23 16:38:10.152668 UTC', 'total_results': 4, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 338
# {'type': 'sale', 'city': 'New York', 'segment': '338', 'date': '2020-12-23 16:38:10.971646 UTC', 'total_results': 4, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 339
# 2076846303
# {'type': 'sale', 'city': 'New York', 'segment': '339', 'date': '2020-12-23 16:38:15.542492 UTC', 'total_results': 5, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 340
# <class 'KeyError'>
# 341
# 64471815
# {'type': 'sale', 'city': 'New York', 'segment': '341', 'date': '2020-12-23 16:38:21.959509 UTC', 'total_results': 5, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 342
# {'type': 'sale', 'city': 'New York', 'segment': '342', 'date': '2020-12-23 16:38:22.642037 UTC', 'total_results': 4, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 343
# 39097238
# {'type': 'sale', 'city': 'New York', 'segment': '343', 'date': '2020-12-23 16:38:27.299178 UTC', 'total_results': 6, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 344
# 2076804157
# 2083689712
# {'type': 'sale', 'city': 'New York', 'segment': '344', 'date': '2020-12-23 16:38:34.769107 UTC', 'total_results': 6, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 345
# {'type': 'sale', 'city': 'New York', 'segment': '345', 'date': '2020-12-23 16:38:35.750260 UTC', 'total_results': 4, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 346
# 68306189
# {'type': 'sale', 'city': 'New York', 'segment': '346', 'date': '2020-12-23 16:38:39.983973 UTC', 'total_results': 3, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 347
# 39868653
# <class 'KeyError'>
# 348
# <class 'KeyError'>
# 349
# {'type': 'sale', 'city': 'New York', 'segment': '349', 'date': '2020-12-23 16:38:49.054745 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 350
# {'type': 'sale', 'city': 'New York', 'segment': '350', 'date': '2020-12-23 16:38:49.891151 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 351
# {'type': 'sale', 'city': 'New York', 'segment': '351', 'date': '2020-12-23 16:38:50.942638 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 352
# {'type': 'sale', 'city': 'New York', 'segment': '352', 'date': '2020-12-23 16:38:52.129615 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 353
# 39048955
# {'type': 'sale', 'city': 'New York', 'segment': '353', 'date': '2020-12-23 16:38:56.685442 UTC', 'total_results': 4, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 354
# 2076904353
# <class 'KeyError'>
# 355
# {'type': 'sale', 'city': 'New York', 'segment': '355', 'date': '2020-12-23 16:39:03.706032 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 356
# 39057219
# 2082265380
# {'type': 'sale', 'city': 'New York', 'segment': '356', 'date': '2020-12-23 16:39:12.352601 UTC', 'total_results': 3, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 357
# {'type': 'sale', 'city': 'New York', 'segment': '357', 'date': '2020-12-23 16:39:13.430418 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 358
# 2077058223
# {'type': 'sale', 'city': 'New York', 'segment': '358', 'date': '2020-12-23 16:39:17.680562 UTC', 'total_results': 2, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 359
# 2078366038
# {'type': 'sale', 'city': 'New York', 'segment': '359', 'date': '2020-12-23 16:39:22.185943 UTC', 'total_results': 2, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 360
# {'type': 'sale', 'city': 'New York', 'segment': '360', 'date': '2020-12-23 16:39:22.708578 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 361
# {'type': 'sale', 'city': 'New York', 'segment': '361', 'date': '2020-12-23 16:39:23.277366 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 362
# {'type': 'sale', 'city': 'New York', 'segment': '362', 'date': '2020-12-23 16:39:23.974715 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 363
# {'type': 'sale', 'city': 'New York', 'segment': '363', 'date': '2020-12-23 16:39:25.000186 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 364
# 70168498
# 72245938
# {'type': 'sale', 'city': 'New York', 'segment': '364', 'date': '2020-12-23 16:39:32.528807 UTC', 'total_results': 5, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 365
# {'type': 'sale', 'city': 'New York', 'segment': '365', 'date': '2020-12-23 16:39:33.501541 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 366
# 2077741517
# {'type': 'sale', 'city': 'New York', 'segment': '366', 'date': '2020-12-23 16:39:37.541319 UTC', 'total_results': 3, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 367
# {'type': 'sale', 'city': 'New York', 'segment': '367', 'date': '2020-12-23 16:39:38.096561 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 368
# <class 'KeyError'>
# 369
# {'type': 'sale', 'city': 'New York', 'segment': '369', 'date': '2020-12-23 16:39:41.391933 UTC', 'total_results': 4, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 370
# {'type': 'sale', 'city': 'New York', 'segment': '370', 'date': '2020-12-23 16:39:42.107727 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 371
# {'type': 'sale', 'city': 'New York', 'segment': '371', 'date': '2020-12-23 16:39:43.132060 UTC', 'total_results': 4, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 372
# 39170755
# <class 'KeyError'>
# 373
# {'type': 'sale', 'city': 'New York', 'segment': '373', 'date': '2020-12-23 16:39:50.098299 UTC', 'total_results': 4, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 374
# {'type': 'sale', 'city': 'New York', 'segment': '374', 'date': '2020-12-23 16:39:51.325965 UTC', 'total_results': 3, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 375
# {'type': 'sale', 'city': 'New York', 'segment': '375', 'date': '2020-12-23 16:39:52.248568 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 376
# {'type': 'sale', 'city': 'New York', 'segment': '376', 'date': '2020-12-23 16:39:53.472959 UTC', 'total_results': 3, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 377
# 248884128
# {'type': 'sale', 'city': 'New York', 'segment': '377', 'date': '2020-12-23 16:39:57.924355 UTC', 'total_results': 1, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 378
# {'type': 'sale', 'city': 'New York', 'segment': '378', 'date': '2020-12-23 16:39:59.005297 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 379
# {'type': 'sale', 'city': 'New York', 'segment': '379', 'date': '2020-12-23 16:39:59.927631 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 380
# <class 'KeyError'>
# 381
# 299035788
# {'type': 'sale', 'city': 'New York', 'segment': '381', 'date': '2020-12-23 16:40:06.412301 UTC', 'total_results': 2, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 382
# {'type': 'sale', 'city': 'New York', 'segment': '382', 'date': '2020-12-23 16:40:07.400631 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 383
# 2076812376
# 39034640
# {'type': 'sale', 'city': 'New York', 'segment': '383', 'date': '2020-12-23 16:40:15.230651 UTC', 'total_results': 4, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 384
# {'type': 'sale', 'city': 'New York', 'segment': '384', 'date': '2020-12-23 16:40:16.309921 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 385
# 39284205
# {'type': 'sale', 'city': 'New York', 'segment': '385', 'date': '2020-12-23 16:40:20.350850 UTC', 'total_results': 4, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 386
# {'type': 'sale', 'city': 'New York', 'segment': '386', 'date': '2020-12-23 16:40:21.124958 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 387
# <class 'KeyError'>
# 388
# {'type': 'sale', 'city': 'New York', 'segment': '388', 'date': '2020-12-23 16:40:24.938555 UTC', 'total_results': 4, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 389
# {'type': 'sale', 'city': 'New York', 'segment': '389', 'date': '2020-12-23 16:40:26.142372 UTC', 'total_results': 6, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 390
# {'type': 'sale', 'city': 'New York', 'segment': '390', 'date': '2020-12-23 16:40:27.066247 UTC', 'total_results': 7, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 391
# <class 'KeyError'>
# 392
# 299034243
# 70168393
# {'type': 'sale', 'city': 'New York', 'segment': '392', 'date': '2020-12-23 16:40:37.462827 UTC', 'total_results': 4, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 393
# 2078434420
# <class 'KeyError'>
# 394
# {'type': 'sale', 'city': 'New York', 'segment': '394', 'date': '2020-12-23 16:40:45.289233 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 395
# {'type': 'sale', 'city': 'New York', 'segment': '395', 'date': '2020-12-23 16:40:46.315246 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 396
# {'type': 'sale', 'city': 'New York', 'segment': '396', 'date': '2020-12-23 16:40:47.544608 UTC', 'total_results': 3, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 397
# 299033655
# <class 'KeyError'>
# 398
# <class 'KeyError'>
# 399
# 39300190
# {'type': 'sale', 'city': 'New York', 'segment': '399', 'date': '2020-12-23 16:41:01.720074 UTC', 'total_results': 1, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 400
# 38956332
# {'type': 'sale', 'city': 'New York', 'segment': '400', 'date': '2020-12-23 16:41:05.703921 UTC', 'total_results': 3, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 401
# {'type': 'sale', 'city': 'New York', 'segment': '401', 'date': '2020-12-23 16:41:06.488120 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 402
# 38965869
# {'type': 'sale', 'city': 'New York', 'segment': '402', 'date': '2020-12-23 16:41:10.932552 UTC', 'total_results': 7, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 403
# {'type': 'sale', 'city': 'New York', 'segment': '403', 'date': '2020-12-23 16:41:11.915456 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 404
# {'type': 'sale', 'city': 'New York', 'segment': '404', 'date': '2020-12-23 16:41:13.146095 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 405
# 38952984
# 183324215
# {'type': 'sale', 'city': 'New York', 'segment': '405', 'date': '2020-12-23 16:41:21.280081 UTC', 'total_results': 7, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 406
# 70162382
# {'type': 'sale', 'city': 'New York', 'segment': '406', 'date': '2020-12-23 16:41:25.513607 UTC', 'total_results': 3, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 407
# 2084165921
# 39378176
# {'type': 'sale', 'city': 'New York', 'segment': '407', 'date': '2020-12-23 16:41:32.941769 UTC', 'total_results': 5, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 408
# 39378039
# {'type': 'sale', 'city': 'New York', 'segment': '408', 'date': '2020-12-23 16:41:37.466431 UTC', 'total_results': 2, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 409
# 39378559
# {'type': 'sale', 'city': 'New York', 'segment': '409', 'date': '2020-12-23 16:41:41.956782 UTC', 'total_results': 2, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 410
# {'type': 'sale', 'city': 'New York', 'segment': '410', 'date': '2020-12-23 16:41:42.736431 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 411
# 39378429
# 2076899204
# {'type': 'sale', 'city': 'New York', 'segment': '411', 'date': '2020-12-23 16:41:50.051457 UTC', 'total_results': 7, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 412
# 39032313
# {'type': 'sale', 'city': 'New York', 'segment': '412', 'date': '2020-12-23 16:41:54.149380 UTC', 'total_results': 6, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 413
# 38998032
# {'type': 'sale', 'city': 'New York', 'segment': '413', 'date': '2020-12-23 16:41:58.445099 UTC', 'total_results': 5, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 414
# 53359683
# 2076827066
# 2096808921
# {'type': 'sale', 'city': 'New York', 'segment': '414', 'date': '2020-12-23 16:42:09.626287 UTC', 'total_results': 7, 'writen_objects': 3, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 415
# 9060054
# {'type': 'sale', 'city': 'New York', 'segment': '415', 'date': '2020-12-23 16:42:13.678507 UTC', 'total_results': 4, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 416
# 39027054
# <class 'KeyError'>
# 417
# {'type': 'sale', 'city': 'New York', 'segment': '417', 'date': '2020-12-23 16:42:20.094307 UTC', 'total_results': 6, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 418
# {'type': 'sale', 'city': 'New York', 'segment': '418', 'date': '2020-12-23 16:42:21.140183 UTC', 'total_results': 9, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 419
# {'type': 'sale', 'city': 'New York', 'segment': '419', 'date': '2020-12-23 16:42:22.064496 UTC', 'total_results': 18, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 420
# {'type': 'sale', 'city': 'New York', 'segment': '420', 'date': '2020-12-23 16:42:22.985322 UTC', 'total_results': 18, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 421
# 39017415
# 9049162
# 39020363
# 83038731
# 9015113
# {'type': 'sale', 'city': 'New York', 'segment': '421', 'date': '2020-12-23 16:42:40.947904 UTC', 'total_results': 20, 'writen_objects': 5, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 422
# {'type': 'sale', 'city': 'New York', 'segment': '422', 'date': '2020-12-23 16:42:42.232990 UTC', 'total_results': 14, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 423
# 9049186
# {'type': 'sale', 'city': 'New York', 'segment': '423', 'date': '2020-12-23 16:42:46.990837 UTC', 'total_results': 5, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 424
# <class 'KeyError'>
# 425
# <class 'KeyError'>
# 426
# 39246037
# 39226800
# {'type': 'sale', 'city': 'New York', 'segment': '426', 'date': '2020-12-23 16:42:59.999800 UTC', 'total_results': 11, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 427
# <class 'KeyError'>
# 428
# ...
# 435
# {'type': 'sale', 'city': 'New York', 'segment': '435', 'date': '2020-12-23 16:43:13.051396 UTC', 'total_results': 4, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 436
# {'type': 'sale', 'city': 'New York', 'segment': '436', 'date': '2020-12-23 16:43:13.973166 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 437
# {'type': 'sale', 'city': 'New York', 'segment': '437', 'date': '2020-12-23 16:43:14.805112 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 438
# {'type': 'sale', 'city': 'New York', 'segment': '438', 'date': '2020-12-23 16:43:15.509412 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 439
# {'type': 'sale', 'city': 'New York', 'segment': '439', 'date': '2020-12-23 16:43:16.430064 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 440
# {'type': 'sale', 'city': 'New York', 'segment': '440', 'date': '2020-12-23 16:43:17.153420 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 441
# {'type': 'sale', 'city': 'New York', 'segment': '441', 'date': '2020-12-23 16:43:18.174839 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 442
# {'type': 'sale', 'city': 'New York', 'segment': '442', 'date': '2020-12-23 16:43:19.196592 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 443
# 39218261
# {'type': 'sale', 'city': 'New York', 'segment': '443', 'date': '2020-12-23 16:43:23.256487 UTC', 'total_results': 2, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 444
# {'type': 'sale', 'city': 'New York', 'segment': '444', 'date': '2020-12-23 16:43:24.219788 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 445
# {'type': 'sale', 'city': 'New York', 'segment': '445', 'date': '2020-12-23 16:43:24.958344 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 446
# 70167686
# {'type': 'sale', 'city': 'New York', 'segment': '446', 'date': '2020-12-23 16:43:29.380210 UTC', 'total_results': 2, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 447
# {'type': 'sale', 'city': 'New York', 'segment': '447', 'date': '2020-12-23 16:43:30.159800 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 448
# 8956488
# 38104914
# {'type': 'sale', 'city': 'New York', 'segment': '448', 'date': '2020-12-23 16:43:37.781631 UTC', 'total_results': 2, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 449
# {'type': 'sale', 'city': 'New York', 'segment': '449', 'date': '2020-12-23 16:43:38.449026 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 450
# {'type': 'sale', 'city': 'New York', 'segment': '450', 'date': '2020-12-23 16:43:39.468236 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 451
# {'type': 'sale', 'city': 'New York', 'segment': '451', 'date': '2020-12-23 16:43:40.494868 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 452
# {'type': 'sale', 'city': 'New York', 'segment': '452', 'date': '2020-12-23 16:43:41.226342 UTC', 'total_results': 3, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 453
# 9013042
# {'type': 'sale', 'city': 'New York', 'segment': '453', 'date': '2020-12-23 16:43:45.358837 UTC', 'total_results': 3, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 454
# {'type': 'sale', 'city': 'New York', 'segment': '454', 'date': '2020-12-23 16:43:46.437000 UTC', 'total_results': 3, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 455
# 8956100
# {'type': 'sale', 'city': 'New York', 'segment': '455', 'date': '2020-12-23 16:43:51.194849 UTC', 'total_results': 2, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 456
# 38105994
# {'type': 'sale', 'city': 'New York', 'segment': '456', 'date': '2020-12-23 16:43:55.715282 UTC', 'total_results': 3, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 457
# {'type': 'sale', 'city': 'New York', 'segment': '457', 'date': '2020-12-23 16:43:56.783243 UTC', 'total_results': 3, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 458
# 8957544
# 39569664
# 65046322
# {'type': 'sale', 'city': 'New York', 'segment': '458', 'date': '2020-12-23 16:44:08.277542 UTC', 'total_results': 8, 'writen_objects': 3, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 459
# 8958453
# 39634670
# 39569593
# 8961541
# {'type': 'sale', 'city': 'New York', 'segment': '459', 'date': '2020-12-23 16:44:22.427030 UTC', 'total_results': 10, 'writen_objects': 4, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 460
# 8961474
# {'type': 'sale', 'city': 'New York', 'segment': '460', 'date': '2020-12-23 16:44:26.508310 UTC', 'total_results': 4, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 461
# 8959908
# 8960989
# {'type': 'sale', 'city': 'New York', 'segment': '461', 'date': '2020-12-23 16:44:32.406885 UTC', 'total_results': 6, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 462
# {'type': 'sale', 'city': 'New York', 'segment': '462', 'date': '2020-12-23 16:44:33.649895 UTC', 'total_results': 3, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 463
# 8959798
# {'type': 'sale', 'city': 'New York', 'segment': '463', 'date': '2020-12-23 16:44:38.092397 UTC', 'total_results': 2, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 464
# {'type': 'sale', 'city': 'New York', 'segment': '464', 'date': '2020-12-23 16:44:38.625624 UTC', 'total_results': 5, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 465
# 8960564
# {'type': 'sale', 'city': 'New York', 'segment': '465', 'date': '2020-12-23 16:44:42.955348 UTC', 'total_results': 3, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 466
# 65047092
# {'type': 'sale', 'city': 'New York', 'segment': '466', 'date': '2020-12-23 16:44:47.055369 UTC', 'total_results': 4, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 467
# {'type': 'sale', 'city': 'New York', 'segment': '467', 'date': '2020-12-23 16:44:47.768635 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 468
# {'type': 'sale', 'city': 'New York', 'segment': '468', 'date': '2020-12-23 16:44:49.100484 UTC', 'total_results': 9, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 469
# <class 'KeyError'>
# 470
# 2079210764
# 38074125
# 87957160
# {'type': 'sale', 'city': 'New York', 'segment': '470', 'date': '2020-12-23 16:45:02.564893 UTC', 'total_results': 7, 'writen_objects': 3, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 471
# {'type': 'sale', 'city': 'New York', 'segment': '471', 'date': '2020-12-23 16:45:03.426012 UTC', 'total_results': 3, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 472
# <class 'KeyError'>
# 473
# 38072567
# <class 'KeyError'>
# 474
# 38067945
# 38068298
# {'type': 'sale', 'city': 'New York', 'segment': '474', 'date': '2020-12-23 16:45:20.998609 UTC', 'total_results': 13, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 475
# {'type': 'sale', 'city': 'New York', 'segment': '475', 'date': '2020-12-23 16:45:21.776066 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 476
# {'type': 'sale', 'city': 'New York', 'segment': '476', 'date': '2020-12-23 16:45:22.491558 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 477
# 38068011
# {'type': 'sale', 'city': 'New York', 'segment': '477', 'date': '2020-12-23 16:45:26.848291 UTC', 'total_results': 3, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 478
# {'type': 'sale', 'city': 'New York', 'segment': '478', 'date': '2020-12-23 16:45:27.607987 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 479
# {'type': 'sale', 'city': 'New York', 'segment': '479', 'date': '2020-12-23 16:45:28.322827 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 480
# {'type': 'sale', 'city': 'New York', 'segment': '480', 'date': '2020-12-23 16:45:29.044544 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 481
# 69518723
# 39572128
# {'type': 'sale', 'city': 'New York', 'segment': '481', 'date': '2020-12-23 16:45:36.464617 UTC', 'total_results': 3, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 482
# 2076829023
# {'type': 'sale', 'city': 'New York', 'segment': '482', 'date': '2020-12-23 16:45:40.773560 UTC', 'total_results': 2, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 483
# 2144450679
# 2076797741
# {'type': 'sale', 'city': 'New York', 'segment': '483', 'date': '2020-12-23 16:45:48.534573 UTC', 'total_results': 4, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 484
# 38181514
# 38181883
# {'type': 'sale', 'city': 'New York', 'segment': '484', 'date': '2020-12-23 16:45:56.747523 UTC', 'total_results': 3, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 485
# {'type': 'sale', 'city': 'New York', 'segment': '485', 'date': '2020-12-23 16:45:57.820600 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 486
# {'type': 'sale', 'city': 'New York', 'segment': '486', 'date': '2020-12-23 16:45:58.741791 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 487
# {'type': 'sale', 'city': 'New York', 'segment': '487', 'date': '2020-12-23 16:45:59.459683 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 488
# {'type': 'sale', 'city': 'New York', 'segment': '488', 'date': '2020-12-23 16:46:00.482263 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 489
# {'type': 'sale', 'city': 'New York', 'segment': '489', 'date': '2020-12-23 16:46:01.405019 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 490
# {'type': 'sale', 'city': 'New York', 'segment': '490', 'date': '2020-12-23 16:46:02.122437 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 491
# {'type': 'sale', 'city': 'New York', 'segment': '491', 'date': '2020-12-23 16:46:03.350057 UTC', 'total_results': 2, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 492
# {'type': 'sale', 'city': 'New York', 'segment': '492', 'date': '2020-12-23 16:46:04.068727 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 493
# <class 'KeyError'>
# 494
# 38181611
# 2077071645
# {'type': 'sale', 'city': 'New York', 'segment': '494', 'date': '2020-12-23 16:46:13.946801 UTC', 'total_results': 3, 'writen_objects': 2, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 495
# {'type': 'sale', 'city': 'New York', 'segment': '495', 'date': '2020-12-23 16:46:14.717855 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 496
# 38171643
# {'type': 'sale', 'city': 'New York', 'segment': '496', 'date': '2020-12-23 16:46:19.678152 UTC', 'total_results': 2, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 497
# {'type': 'sale', 'city': 'New York', 'segment': '497', 'date': '2020-12-23 16:46:20.451346 UTC', 'total_results': 3, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 498
# {'type': 'sale', 'city': 'New York', 'segment': '498', 'date': '2020-12-23 16:46:21.373261 UTC', 'total_results': 1, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 499
# 64445549
# {'type': 'sale', 'city': 'New York', 'segment': '499', 'date': '2020-12-23 16:46:25.926152 UTC', 'total_results': 6, 'writen_objects': 1, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
# 500
# {'type': 'sale', 'city': 'New York', 'segment': '500', 'date': '2020-12-23 16:46:26.699343 UTC', 'total_results': 0, 'writen_objects': 0, 'write_errors': 0, 'broken_responses_top': '', 'broken_responses_low': '', 'errors': '', 'bq_errors': ''}
